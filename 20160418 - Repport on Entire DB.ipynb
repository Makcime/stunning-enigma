# %%
# %matplotlib inline
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from analyser import *

# %%
subs = import_all_submissions(dbname="test1")

# %%
#mat, d1, a1 = process(subs, meth='lin', kind='bin', vert_name="DiffLinBin", hor_name='AbilLinBin', verbose=False)
#mat, d2, a2 = process(subs, meth='lin', kind='means', vert_name="DiffLinMeans", hor_name='AbilLinMeans', verbose=False)
mat, d3, a3 = process(subs, meth='svd', kind='bin', 
                          vert_name="DiffSvdBin", hor_name='AbilSvdBin', verbose=True)
# Out:
# Proceed in 64.114 seconds
# Using the svd method
# Based on the bin matrix
# For 7539 users and 1191 problems

# %%
mat, d4, a4 = process(subs, meth='svd', kind='means', 
                      vert_name="DiffSvdMeans", hor_name='AbilSvdMeans', verbose=True)
# Out:
# Proceed in 235.843 seconds
# Using the svd method
# Based on the means matrix
# For 7539 users and 1191 problems

# %%
Difficulties = pd.DataFrame([d3, d4]).T
Abilities = pd.DataFrame([a3, a4]).T

# %% [markdown]
# # Difficulties comparison

# %%
g = Difficulties[["DiffSvdMeans", "DiffSvdBin"]].sort_values(by='DiffSvdMeans', inplace=False)
g.plot(kind='line')
# Out:
# <img src="data:image/png;base64,...">

# %%
g = Difficulties[["DiffSvdMeans", "DiffSvdBin"]].sort_values(by='DiffSvdMeans', inplace=False)
g.plot(kind='kde')
# Out:
# <img src="data:image/png;base64,...">

# %%
g = Difficulties[["DiffSvdMeans", "DiffSvdBin"]].sort_values(by='DiffSvdMeans', inplace=False)
g.plot(kind='hist',subplots=True, bins=20)
# Out:
# <img src="data:image/png;base64,...">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff0995904d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff09adb57d0>], dtype=object)

# %% [markdown]
# # Abilities Comparison

# %%
g = Abilities[["AbilSvdMeans", "AbilSvdBin"]].sort_values(by='AbilSvdMeans', inplace=False)
g.plot(kind='line',subplots=False, )
# Out:
# <img src="data:image/png;base64,...">

# %%
g.plot(kind='kde',subplots=False)
# Out:
# <img src="data:image/png;base64,...">

# %%
g.plot(kind='hist',subplots=True)
# Out:
# <img src="data:image/png;base64,...">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff094a7b910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7ff093a4a8d0>], dtype=object)
